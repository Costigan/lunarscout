# %%
# %load_ext autoreload
# %autoreload 2

import lunarscout
from renderscout.remote import connect

with connect() as rs:
    camera = rs.app.camera.get_state()
    terrain = rs.app.get_terrain_point_metadata(
        longitude_degrees=31.6218,
        latitude_degrees=-85.42088,
    )

camera, terrain
